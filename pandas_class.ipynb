# %%
import pandas as pd

# %% [markdown]
# ## 1. Pandas will help to do all the tasks related to the data(table, text, csv, json , html, excel) ex: data loading, transorming, cleaning, analysing, etc.
# ## 2. Pandas two Called Dataframe or pandas DataFrame, Series.
# ## 3. Every DataFrame contains rows and columns

# %% [markdown]
# # Data Types
#
# ## 1. categorical data --> String
#     --> Nominal Data --> string (Nominal data dont have any relation between the categories)(colur: black, blue, red)
#     --> Ordinal Data --> string (Ordinal data you have relation) (size: s, l, xl, xxl, xxxl)
# ## 2. Numerical data
#
# ## 3. Time Seires data
#
# ## 4. Binary Data

# %%
# Basic Example 
# creating a data frame using Pandas


d = {
    'col1': [1, 2], 
    'col2': [3, 4],
    'col3': [5,6]
}

df = pd.DataFrame(d)

# %%
df
# Out:
#    col1  col2  col3
# 0     1     3     5
# 1     2     4     6

# %%
df.shape
# Out:
# (2, 3)

# %%
df_heart = pd.read_csv("heart.csv")

# %%
df_heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # SERIES

# %%
# individual column in the data freame you call it as series

s = df.col1
type(s)
# Out:
# pandas.core.series.Series

# %%
df_heart.head() # first 5 rows
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df_heart.tail() # last firve rows
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df_heart.head(2000)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df_heart.tail(10)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 908   63   M           ASY        140          187          0        LVH
# 909   63   F           ASY        124          197          0     Normal
# 910   41   M           ATA        120          157          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 908    144              Y      4.0       Up             1
# ...

# %%
df_heart.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df_heart.shape
# Out:
# (918, 12)

# %%
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df_heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
d = df_heart.ChestPainType

# %%
d
# Out:
# 0      ATA
# 1      NAP
# 2      ATA
# 3      ASY
# 4      NAP
#       ...
# 913     TA
# 914    ASY
# 915    ASY
# 916    ATA
# 917    NAP
# Name: ChestPainType, Length: 918, dtype: object

# %%
age = df_heart['Age']
age
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %%
age= df_heart.iloc[:2,:]
age
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
col = ['Age', 'Sex']
df_heart[col]
# Out:
#      Age Sex
# 0     40   M
# 1     49   F
# 2     37   M
# 3     48   F
# 4     54   M
# ..   ...  ..
# 913   45   M
# 914   68   M
# 915   57   M
# 916   57   F
# 917   38   M
#
# [918 rows x 2 columns]

# %%
df_heart[["Age","Sex"]]
# Out:
#      Age Sex
# 0     40   M
# 1     49   F
# 2     37   M
# 3     48   F
# 4     54   M
# ..   ...  ..
# 913   45   M
# 914   68   M
# 915   57   M
# 916   57   F
# 917   38   M
#
# [918 rows x 2 columns]

# %% [markdown]
# # Data Filtering

# %% [markdown]
# # 1. Select all the rows where Age>40

# %%
df_heart[df_heart['Age']>40]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# 6     45   F           ATA        130          237          0     Normal
# 7     54   M           ATA        110          208          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df_heart[ df_heart['Age']>40 ] # fillter the data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# 6     45   F           ATA        130          237          0     Normal
# 7     54   M           ATA        110          208          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # Select all the male memebers in the datasets

# %% [markdown]
# df_heart[ df_heart["Sex"]=="M" ]

# %% [markdown]
# # Males with age >40

# %%
df_heart[ (df_heart["Sex"]=="M") & (df_heart["Age"]>40) ]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 4     54   M           NAP        150          195          0     Normal
# 7     54   M           ATA        110          208          0     Normal
# 11    58   M           ATA        136          164          0         ST
# 13    49   M           ASY        140          234          0     Normal
# 18    60   M           ASY        100          248          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 910   41   M           ATA        120          157          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df_heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # create a column which is a sum of AGE + Cholesterol

# %%
ac = df_heart["Age"] + df_heart["Cholesterol"]

# %%
df_heart["age_cholestrol"] = ac

# %%
df_heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  age_cholestrol
# 0              N      0.0       Up             0             329
# 1              N      1.0     Flat             1             229
# 2              N      0.0       Up             0             320
# 3              Y      1.5     Flat             1             262
# 4              N      0.0       Up             0             249

# %% [markdown]
# # Creating the columns

# %%
df_heart["age_cholestrol_new"] = df_heart["Age"] * df_heart["Cholesterol"]
df_heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  age_cholestrol  \
# 0              N      0.0       Up             0             329
# 1              N      1.0     Flat             1             229
# 2              N      0.0       Up             0             320
# 3              Y      1.5     Flat             1             262
# 4              N      0.0       Up             0             249
#
#    age_cholestrol_new
# 0               11560
# 1                8820
# 2               10471
# ...

# %% [markdown]
# # Saving DataFrame to the local csv file

# %%
df_heart.to_csv("new_csv_file.csv")
df_heart.to

# %% [markdown]
# # statiscal summary for the DataFrame

# %%
df_heart.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease  age_cholestrol  age_cholestrol_new
# count  918.000000    918.000000      918.000000          918.000000
# mean     0.887364      0.553377      252.310458        10539.739651
# std      1.066570      0.497414      108.890982         6231.826455
# min     -2.600000      0.000000       32.000000            0.000000
# ...

# %%
df_heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  age_cholestrol
# 0              N      0.0       Up             0             329
# 1              N      1.0     Flat             1             229
# 2              N      0.0       Up             0             320
# 3              Y      1.5     Flat             1             262
# 4              N      0.0       Up             0             249

# %% [markdown]
# #  Renaming the Columns

# %%
df_heart = df_heart.iloc[:,:-1]

# %%
df_heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  age_cholestrol
# ...

# %% [markdown]
# # Rename the particular column

# %%
df_heart_new.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  age_cholestrol
# 0              N      0.0       Up             0             329
# 1              N      1.0     Flat             1             229
# 2              N      0.0       Up             0             320
# 3              Y      1.5     Flat             1             262
# 4              N      0.0       Up             0             249

# %%
df_heart_new.rename(columns={"Sex": "Gender", "Cholesterol": "chol"}, inplace=True)

# %%
df_heart_new
# Out:
#      Age Gender ChestPainType  RestingBP  chol  FastingBS RestingECG  MaxHR  \
# 0     40      M           ATA        140   289          0     Normal    172
# 1     49      F           NAP        160   180          0     Normal    156
# 2     37      M           ATA        130   283          0         ST     98
# 3     48      F           ASY        138   214          0     Normal    108
# 4     54      M           NAP        150   195          0     Normal    122
# ..   ...    ...           ...        ...   ...        ...        ...    ...
# 913   45      M            TA        110   264          0     Normal    132
# 914   68      M           ASY        144   193          1     Normal    141
# 915   57      M           ASY        130   131          0     Normal    115
# 916   57      F           ATA        130   236          0        LVH    174
# 917   38      M           NAP        138   175          0     Normal    173
#
# ...
