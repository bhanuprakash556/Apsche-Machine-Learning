# %%
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib

# %% [markdown]
# # 1. Basic plots . how to draw basic plots using Matplotlib.
#     --> line , scatter, bar,
# # 2. Subplots
# # 3. How to save drawn plots into images
# # 4. Drawing Plots using seaborn
# # 5. saving plots create using seaborn

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# %%
# import matplotlib.pyplot as plt

plt.plot(x, y)
plt.title("line plot")
plt.xlabel("x- axis")
plt.ylabel("y - axis")
plt.show()

# %%
plt.scatter(x, y)
plt.title("scatter plot using x and y")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
plt.scatter(x, y)
plt.title("scatter plot using x and y")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

plt.scatter(x_m, y_m)
plt.title("scatter plot using x and y")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x_m = [14, 24, 34, 44]
y_m = [50, 60, 75, 80]

# %%
plt.scatter(x, y)
plt.scatter(y,x)
plt.scatter(x_m, y_m)
plt.title("scatter plot using x and y")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## How to create subplots in matplotlib

# %%
plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(y,x)

# plt.subplot(2,2,3)
# plt.plot(y,x)


# plt.subplot(2,2,4)
# plt.plot(y,x)


plt.show()
plt.savefig("plot.jpg")

# %%
plt.savefig("plot1.jpg")

# %%
import seaborn as sns

# %%
x ,y
# Out:
# ([1, 2, 3, 4], [10, 20, 25, 30])

# %%
sns.scatterplot(x= x, y = y,)

# %%
sns.distplot(x)
# Out:
# <ipython-input-33-5ec1fbeebf40>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>

# %%
# matplot numpy mathematical calculations

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
age = df.Age
chol = df.Cholesterol

# %%
sns.scatterplot(x = age, y= chol)
# Out:
# <Axes: xlabel='Age', ylabel='Cholesterol'>

# %%
age = df.Age
chol = df.Cholesterol
rest_bp = df.RestingBP

# %%
plt.scatter(age,rest_bp)
plt.xlabel("age")
plt.ylabel("chol")
plt.show()

# %%
sns.scatterplot(data=df,x = "Age", y = "FastingBS")
# Out:
# <Axes: xlabel='Age', ylabel='FastingBS'>

# %%
sns.scatterplot(data=df,x = "Age", y = "RestingBP")
plt.savefig("newplot.jpg")
